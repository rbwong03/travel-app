# %%
from utils import cities, first_names, last_names, adjectives
import random
import hashlib
import string
from datetime import datetime, timedelta


def get_random_date(start_year=2000, end_year=2024):
    random_datetime = get_random_datetime(start_year, end_year)
    return random_datetime.date()


def get_random_datetime(start_year=2000, end_year=2024):
    start_date = datetime(start_year, 1, 1, 0, 0, 0)
    end_date = datetime(end_year, 12, 31, 23, 59, 59)
    
    time_diff = end_date - start_date
    
    random_seconds = random.randint(0, int(time_diff.total_seconds()))
    random_date = start_date + timedelta(seconds=random_seconds)
    
    return random_date


def get_datetime_within_next_day(given_date_str):
    
    given_date = datetime.strptime(given_date_str, '%Y-%m-%d')
    
    start_datetime = given_date + timedelta(days=1)
    
    random_datetime = start_datetime + timedelta(seconds=random.randint(0, 86399))
    
    return random_datetime

def random_decimal(min_val=0, max_val=10, precision=1):
    range_start = min_val * 10**precision
    range_end = max_val * 10**precision
    

    random_num = random.randint(range_start, range_end) / 10**precision
    
    return random_num

def make_salt():
    char_set = string.printable[:95].replace("'", "").replace('"', "")
    salt = ''.join(random.choice(char_set) for _ in range(8))
    return salt


def hash_password_with_salt(salt):
    salted_password = 'password' + salt
    hash_obj = hashlib.sha256()
    
    hash_obj.update(salted_password.encode('utf-8'))
    
    return hash_obj.hexdigest()

# %%
def generate_city_table():
    for i in cities:
        city_name = cities[i]['city_name']
        country_name = cities[i]['country_name']
        state_name = cities[i].get('state_name', 'NULL')
        population = random.randint(100000, 1000000)
        fun_fact = f"This is a fun fact about {city_name}, {country_name}."

        state_value = state_name if state_name != 'NULL' else state_name
        print(f"""INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
                  VALUES ('{city_name}', {state_value}, '{country_name}', {population}, '{fun_fact}');""")

generate_city_table()
# Out:
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('New York', New York, 'United States', 684202, 'This is a fun fact about New York, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Los Angeles', California, 'United States', 179838, 'This is a fun fact about Los Angeles, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Chicago', Illinois, 'United States', 844790, 'This is a fun fact about Chicago, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Houston', Texas, 'United States', 295955, 'This is a fun fact about Houston, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Austin', Texas, 'United States', 426698, 'This is a fun fact about Austin, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('San Francisco', California, 'United States', 746536, 'This is a fun fact about San Francisco, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Seattle', Washington, 'United States', 683232, 'This is a fun fact about Seattle, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Boston', Massachusetts, 'United States', 640615, 'This is a fun fact about Boston, United States.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Toronto', NULL, 'Canada', 326414, 'This is a fun fact about Toronto, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Montreal', NULL, 'Canada', 795740, 'This is a fun fact about Montreal, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Vancouver', NULL, 'Canada', 706383, 'This is a fun fact about Vancouver, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Calgary', NULL, 'Canada', 648393, 'This is a fun fact about Calgary, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Edmonton', NULL, 'Canada', 537512, 'This is a fun fact about Edmonton, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Ottawa', NULL, 'Canada', 489643, 'This is a fun fact about Ottawa, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Winnipeg', NULL, 'Canada', 677286, 'This is a fun fact about Winnipeg, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Quebec City', NULL, 'Canada', 881058, 'This is a fun fact about Quebec City, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Hamilton', NULL, 'Canada', 139903, 'This is a fun fact about Hamilton, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('London', NULL, 'Canada', 824110, 'This is a fun fact about London, Canada.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Madrid', NULL, 'Spain', 730981, 'This is a fun fact about Madrid, Spain.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Barcelona', NULL, 'Spain', 293250, 'This is a fun fact about Barcelona, Spain.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Valencia', NULL, 'Spain', 538384, 'This is a fun fact about Valencia, Spain.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('
Brazil.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Porto Alegre', NULL, 'Brazil', 112611, 'This is a fun fact about Porto Alegre, Brazil.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Seoul', NULL, 'Korea', 872908, 'This is a fun fact about Seoul, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Busan', NULL, 'Korea', 101841, 'This is a fun fact about Busan, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Incheon', NULL, 'Korea', 553426, 'This is a fun fact about Incheon, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Daegu', NULL, 'Korea', 117787, 'This is a fun fact about Daegu, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Daejeon', NULL, 'Korea', 562637, 'This is a fun fact about Daejeon, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Gwangju', NULL, 'Korea', 223794, 'This is a fun fact about Gwangju, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Ulsan', NULL, 'Korea', 908207, 'This is a fun fact about Ulsan, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Suwon', NULL, 'Korea', 460101, 'This is a fun fact about Suwon, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Changwon', NULL, 'Korea', 875286, 'This is a fun fact about Changwon, Korea.');
# INSERT INTO city_info (city_name, state_name, country_name, population, fun_fact)
#                   VALUES ('Seongnam', NULL, 'Korea', 865903, 'This is a fun fact about Seongnam, Korea.');

# %%
def create_user():
    first_name = random.choice(first_names)
    last_name = random.choice(last_names)
    random_number = random.randint(1, 999)
    profile_pic = 'random_file_path'
    salt = make_salt()
    password_hash = hash_password_with_salt(salt)

    username = first_name + last_name + str(random_number)
    email = username + '@gmail.com'

    return username, email, profile_pic, salt, password_hash

def generate_user(user_id, visit_id):

    # creates the insert statement for the user_info table
    username, email, profile_pic, salt, password_hash = create_user()
    insert_user_info = f"INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES ({user_id}, '{username}', '{email}', '{profile_pic}', '{salt}', '{password_hash}');"

    print(insert_user_info)

    # creates the insert statements for the visited table
    for _ in range(random.randint(1, 5)):
        city_id = random.randint(1, len(cities))
        picture = 'random_file_path'
        start_date = get_random_date()
        end_date = start_date + timedelta(random.randint(0, 7))
        time_inputted = get_datetime_within_next_day(str(end_date))
        rating = random_decimal()
        review = f"I thought this place was very {random.choice(adjectives)}!"

        print(f"""INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
        VALUES ({visit_id}, {user_id}, {city_id}, '{review}', {rating}, '{start_date}', '{end_date}', '{time_inputted}');""")

        for _ in range(random.randint(1, 10)):
            picture = ''.join(random.choices(string.ascii_letters + string.digits, k=10))

            print(f"""INSERT INTO pictures (visit_id, picture) VALUES ({visit_id}, '{picture}');""")
        
        visit_id += 1

    return user_id + 1, visit_id

def generate_wishlist(num_users):
    for i in range(1, num_users + 1):
        num_wishes = random.randint(5, 15)
        cities = list(range(1, 119))
        
        for _ in range(num_wishes):
            city_id = random.choice(cities)
            cities.remove(city_id)
            time_inputted = get_random_datetime()
            print(f"""INSERT INTO wishlist (user_id, city_id, time_inputted)
            VALUES ({i}, {city_id}, '{time_inputted}');""")

# %%
def create_user():
    first_name = random.choice(first_names)
    last_name = random.choice(last_names)
    random_number = random.randint(1, 999)
    profile_pic = 'random_file_path'
    salt = make_salt()
    password_hash = hash_password_with_salt(salt)

    username = first_name + last_name + str(random_number)
    email = username + '@gmail.com'

    return username, email, profile_pic, salt, password_hash

def generate_user_visited_reviews(user_id, visit_id, review_id):

    # creates the insert statement for the user_info table
    username, email, profile_pic, salt, password_hash = create_user()
    insert_user_info = f"INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES ({user_id}, '{username}', '{email}', '{profile_pic}', '{salt}', '{password_hash}');"

    print(insert_user_info)

    # creates the insert statements for the visited table
    for _ in range(random.randint(1, 5)):
        city_id = random.randint(1, len(cities))
        picture = 'random_file_path'
        start_date = get_random_date()
        end_date = start_date + timedelta(random.randint(0, 7))
        time_inputted = get_datetime_within_next_day(str(end_date))
        print(f"""INSERT INTO visited (visit_id, user_id, city_id, picture, start_date, end_date, time_inputted)
        VALUES ({visit_id}, {user_id}, {city_id}, '{picture}', '{start_date}', '{end_date}', '{time_inputted}');""")
        
        # creates the insert statements for the review table
        rating = random_decimal()
        review = f"I thought this place was very {random.choice(adjectives)}!"
        print(f"""INSERT INTO reviews (review_id, visit_id, user_id, city_id, rating, review, time_inputted)
        VALUES ({review_id}, {visit_id}, {user_id}, {city_id}, {rating}, '{review}', '{end_date}');""")
        visit_id += 1
        review_id += 1

    return user_id + 1, visit_id, review_id

def generate_wishlist(num_users):
    for i in range(1, num_users + 1):
        num_wishes = random.randint(5, 15)
        cities = list(range(1, 119))
        for _ in range(num_wishes):
            city_id = random.choice(cities)
            cities.remove(city_id)
            time_inputted = get_random_datetime()
            print(f"""INSERT INTO wishlist (user_id, city_id, time_inputted)
            VALUES ({i}, {city_id}, '{time_inputted}');""")

# %%
user_id = 1
visit_id = 1
num_users = 20
# generates the user
for i in range(num_users):
    user_id, visit_id = generate_user(user_id, visit_id)

generate_wishlist(num_users)
# Out:
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (1, 'VioletJordan547', 'VioletJordan547@gmail.com', 'random_file_path', '.i(TL>L8', '5cac68e6b9cfd29b5e258554b9b11c480bbc50f92cad103f2c69d800730cf2ac');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (1, 1, 32, 'I thought this place was very jaw-dropping!', 8.4, '2000-12-08', '2000-12-10', '2000-12-11 21:40:18');
# INSERT INTO pictures (visit_id, picture) VALUES (1, '0tIpRaAw5a');
# INSERT INTO pictures (visit_id, picture) VALUES (1, 'TnLq89m14r');
# INSERT INTO pictures (visit_id, picture) VALUES (1, '8yEoprdKKP');
# INSERT INTO pictures (visit_id, picture) VALUES (1, 'JCl7L97Rjj');
# INSERT INTO pictures (visit_id, picture) VALUES (1, 'oiEk61KBQI');
# INSERT INTO pictures (visit_id, picture) VALUES (1, 'lXfaahTFBy');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (2, 1, 61, 'I thought this place was very mind-bending!', 4.8, '2023-12-08', '2023-12-14', '2023-12-15 04:17:18');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'BLB8sdr9bI');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'fYEVuelxYM');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'xkQ7O5xxie');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'UWCAgrN8LQ');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'k05FFJEeVC');
# INSERT INTO pictures (visit_id, picture) VALUES (2, '1YaD7O87VD');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'm8HNutb7ot');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'bL5qzp9nav');
# INSERT INTO pictures (visit_id, picture) VALUES (2, 'YhBkTIJYlT');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (3, 1, 104, 'I thought this place was very stunning!', 2.7, '2021-10-19', '2021-10-22', '2021-10-23 16:34:13');
# INSERT INTO pictures (visit_id, picture) VALUES (3, 'uI2QvzztJt');
# INSERT INTO pictures (visit_id, picture) VALUES (3, '3Q7qmOMeGt');
# INSERT INTO pictures (visit_id, picture) VALUES (3, 'ef9R9IN6IF');
# INSERT INTO pictures (visit_id, picture) VALUES (3, 'LEDwLB0EV9');
# INSERT INTO pictures (visit_id, picture) VALUES (3, 'gGeY6gFIoj');
# INSERT INTO pictures (visit_id, picture) VALUES (3, 'ZjMNwo2JyH');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (4, 1, 100, 'I thought this place was very enjoyable!', 8.3, '2014-02-10', '2014-02-15', '2014-02-16 16:04:16');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'waCRdX4Bzu');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'kT5Utfnqo6');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'vB9eHXH72Q');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'aLy8baoBqf');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'szZJ2V4TbK');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'vF5MByMB8D');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'HuRh1Wb3YP');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'lOqmpTLkoW');
# INSERT INTO pictures (visit_id, picture) VALUES (4, 'KHLJyKHIIs');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (5, 1, 34, 'I thought this place was very terrific!', 1.4, '2015-05-14', '2015-05-18', '2015-05-19 16:34:13');
# INSERT INTO pictures (visit_id, picture) VALUES (5, '8b0UOaaFOa');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'AnvcRxYSvF');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'XsYLXz103C');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'X0clhhDJ9m');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'wzhiKp0QUp');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'nYdIlg1rOm');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'egpWA3Ab4g');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'Sf9DjwAJgB');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'm6R2TFdawq');
# INSERT INTO pictures (visit_id, picture) VALUES (5, 'W2jeNfHuOO');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (2, 'DavidLi714', 'DavidLi714@gmail.com', 'random_file_path', 'Z(>Y.U!s', 'b125a3d4436190fc230e0051c2b08810c721ec5bace361e8ac407f52f55cf301');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (6, 2, 87, 'I thought this place was very mind-boggling!', 0.5, '2016-05-08', '2016-05-14', '2016-05-15 01:46:44');
# INSERT INTO pictures (visit_id, picture) VALUES (6, 'FqqZf375uv');
# INSERT INTO pictures (visit_id, picture) VALUES (6, 'JvXLKkGdKd');
# INSERT INTO pictures (visit_id, picture) VALUES (6, 'oJ45yQmVn8');
# INSERT INTO pictures (visit_id, picture) VALUES (6, 'e7LW8gtF9I');
# INSERT INTO pictures (visit_id, picture) VALUES (6, 'AkO0USsdvf');
# INSERT INTO pictures (visit_id, picture) VALUES (6, 'nMnRzScZCi');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (3, 'JohnStewart823', 'JohnStewart823@gmail.com', 'random_file_path', '*RDt=U9&', 'c299f0c0054f3dad28e290d903e9242b7c4781dc2f4d8ff5b3020e5ff462b56c');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (7, 3, 57, 'I thought this place was very magnificent!', 3.5, '2002-10-19', '2002-10-19', '2002-10-20 09:51:41');
# INSERT INTO pictures (visit_id, picture) VALUES (7, 'GJfmW9NSqo');
# INSERT INTO pictures (visit_id, picture) VALUES (7, '7VZct4wINp');
# INSERT INTO pictures (visit_id, picture) VALUES (7, 't2TnaXfG0l');
# INSERT INTO pictures (visit_id, picture) VALUES (7, '2QlZ8QXzO4');
# INSERT INTO pictures (visit_id, picture) VALUES (7, '7Nj5qWsR5G');
# INSERT INTO pictures (visit_id, picture) VALUES (7, 'x3jlJKnzRL');
# INSERT INTO pictures (visit_id, picture) VALUES (7, 'BlTyQjObWn');
# INSERT INTO pictures (visit_id, picture) VALUES (7, 'xpiDJxati0');
# INSERT INTO pictures (visit_id, picture) VALUES (7, 'NAc2oZriuh');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (8, 3, 61, 'I thought this place was very incredible!', 1.2, '2021-09-15', '2021-09-17', '2021-09-18 02:30:08');
# INSERT INTO pictures (visit_id, picture) VALUES (8, 'Yz5j9cYZIg');
# INSERT INTO pictures (visit_id, picture) VALUES (8, 'f1McjFDT8P');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (9, 3, 89, 'I thought this place was very eye-opening!', 7.3, '2015-02-01', '2015-02-08', '2015-02-09 07:03:20');
# INSERT INTO pictures (visit_id, picture) VALUES (9, 'Ia49zVOGrd');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (10, 3, 68, 'I thought this place was very splendid!', 0.9, '2013-12-10', '2013-12-11', '2013-12-12 06:32:09');
# INSERT INTO pictures (visit_id, picture) VALUES (10, 'MlRJIfyHvB');
# INSERT INTO pictures (visit_id, picture) VALUES (10, 'qAbHT5KnHQ');
# INSERT INTO pictures (visit_id, picture) VALUES (10, 'UsQeIzYR0P');
# INSERT INTO pictures (visit_id, picture) VALUES (10, '4XtSmEKWbY');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (4, 'IanParker992', 'IanParker992@gmail.com', 'random_file_path', '0u)z)-P_', '6f3d41ae3846f96bea36fdb09c2d78f9c1bda0a63156c5af0e68e1fa3c2eaac3');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (11, 4, 53, 'I thought this place was very fun!', 8.6, '2003-10-27', '2003-10-30', '2003-10-31 18:01:59');
# INSERT INTO pictures (visit_id, picture) VALUES (11, '9q63aLnVLI');
# INSERT INTO pictures (visit_id, picture) VALUES (11, 'wMbn3kjPbz');
# INSERT INTO pictures (visit_id, picture) VALUES (11, 'fA4BGl0ACm');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (12, 4, 117, 'I thought this place was very superb!', 5.3, '2009-11-03', '2009-11-08', '2009-11-09 05:00:40');
# INSERT INTO pictures (visit_id, picture) VALUES (12, '71unQ6stRG');
# INSERT INTO pictures (visit_id, picture) VALUES (12, 'Njlcn7KyPj');
# INSERT INTO pictures (visit_id, picture) VALUES (12, 'blts2F7qAL');
# INSERT INTO pictures (visit_id, picture) VALUES (12, 'zX9uXiauTl');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (13, 4, 94, 'I thought this place was very eye-opening!', 2.2, '2008-05-02', '2008-05-04', '2008-05-05 07:56:34');
# INSERT INTO pictures (visit_id, picture) VALUES (13, 'SgIpcFlbkj');
# INSERT INTO pictures (visit_id, picture) VALUES (13, '3MdtgkNBFP');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (5, 'RyanWood482', 'RyanWood482@gmail.com', 'random_file_path', '*a@RPpnk', '6a80ffa227758e01ac8e50239fdc3edc25bd9118d94adb7604bb22e89ca49d92');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (14, 5, 4, 'I thought this place was very memorable!', 5.5, '2015-06-19', '2015-06-26', '2015-06-27 12:00:42');
# INSERT INTO pictures (visit_id, picture) VALUES (14, 'jtol51M78c');
# INSERT INTO pictures (visit_id, picture) VALUES (14, 'MhRZV1FMOH');
# INSERT INTO pictures (visit_id, picture) VALUES (14, 'ycAfpgNIcJ');
# INSERT INTO pictures (visit_id, picture) VALUES (14, 'SB8i7Oo1cM');
# INSERT INTO pictures (visit_id, picture) VALUES (14, 'UZG04wospn');
# INSERT INTO pictures (visit_id, picture) VALUES (14, 'Va7K6QXu1v');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (6, 'EmmaMartin586', 'EmmaMartin586@gmail.com', 'random_file_path', '=z-Tmfq.', '13e216d09b3f7820116d377e902df44c117e31abd841261ab2ba9b09d44ec775');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (15, 6, 53, 'I thought this place was very beautiful!', 7.2, '2007-10-06', '2007-10-06', '2007-10-07 23:08:04');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'AclO1C37iZ');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'RkYejS2IfU');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'hl2sal6Vmn');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'dFyAEa0IUC');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'cCiyP0RqiK');
# INSERT INTO pictures (visit_id, picture) VALUES (15, '7bpQoYoMYN');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'XgLgCK1M5o');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'yzzuUItVWK');
# INSERT INTO pictures (visit_id, picture) VALUES (15, 'oqWpXbVK37');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (16, 6, 64, 'I thought this place was very terrific!', 2.7, '2019-11-21', '2019-11-22', '2019-11-23 13:41:18');
# INSERT INTO pictures (visit_id, picture) VALUES (16, 'BJLuMQnIrQ');
# INSERT INTO pictures (visit_id, picture) VALUES (16, '5W26ze1caL');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (17, 6, 45, 'I thought this place was very exciting!', 5.6, '2004-06-25', '2004-07-02', '2004-07-03 02:15:10');
# INSERT INTO pictures (visit_id, picture) VALUES (17, 'buFdickhlb');
# INSERT INTO pictures (visit_id, picture) VALUES (17, 'IfKZcD99Hp');
# INSERT INTO pictures (visit_id, picture) VALUES (17, '7ORNR0mZ9f');
# INSERT INTO pictures (visit_id, picture) VALUES (17, 'Y7NF3nCEHj');
# INSERT INTO pictures (visit_id, picture) VALUES (17, 'mMfMmiC6mZ');
# INSERT INTO pictures (visit_id, picture) VALUES (17, 'HKZYIJRbj8');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (18, 6, 113, 'I thought this place was very fantastic!', 4.6, '2007-08-31', '2007-09-07', '2007-09-08 15:32:15');
# INSERT INTO pictures (visit_id, picture) VALUES (18, 'bUPwtHHg9D');
# INSERT INTO pictures (visit_id, picture) VALUES (18, 'vYLmbe5H4H');
# INSERT INTO pictures (visit_id, picture) VALUES (18, '3Z4fyqdSPI');
# INSERT INTO pictures (visit_id, picture) VALUES (18, 'cuTp2NPsXC');
# INSERT INTO pictures (visit_id, picture) VALUES (18, 'Mvf7Sxzls4');
# INSERT INTO pictures (visit_id, picture) VALUES (18, '1Jqk9ZWlIi');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (19, 6, 56, 'I thought this place was very lovely!', 1.7, '2012-05-05', '2012-05-06', '2012-05-07 05:51:04');
# INSERT INTO pictures (visit_id, picture) VALUES (19, 'i7InelbXYZ');
# INSERT INTO pictures (visit_id, picture) VALUES (19, 'GSMWs9yD0m');
# INSERT INTO pictures (visit_id, picture) VALUES (19, '3LY70xiDFz');
# INSERT INTO pictures (visit_id, picture) VALUES (19, 'jertoo7Xnq');
# INSERT INTO pictures (visit_id, picture) VALUES (19, 'h07Svs2zDQ');
# INSERT INTO pictures (visit_id, picture) VALUES (19, '9Lz4YZOqOf');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (7, 'ZacharyParker462', 'ZacharyParker462@gmail.com', 'random_file_path', '$\YF=<$U', 'd74546debfd974f90cfee630be72f756358a76781cd96b95e1c4dacea152ba1d');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (20, 7, 71, 'I thought this place was very mind-blowing!', 7.7, '2018-03-20', '2018-03-23', '2018-03-24 09:11:20');
# INSERT INTO pictures (visit_id, picture) VALUES (20, 'v4DVLOlbhT');
# INSERT INTO pictures (visit_id, picture) VALUES (20, 'WNluYNKIGX');
# INSERT INTO pictures (visit_id, picture) VALUES (20, 'Gpd5swqnyD');
# INSERT INTO pictures (visit_id, picture) VALUES (20, 'BMRAH4Vc94');
# INSERT INTO pictures (visit_id, picture) VALUES (20, 'PyrZlxQXOP');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (21, 7, 44, 'I thought this place was very extraordinary!', 7.0, '2021-03-08', '2021-03-10', '2021-03-11 23:33:00');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'RO8ylpRgZd');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'Qz0VshhnWT');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'BD3JFQo4cz');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'BNhCBdrqdj');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'qakIQHWUeR');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'OGPJ36YASC');
# INSERT INTO pictures (visit_id, picture) VALUES (21, 'UABuj98RXe');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (22, 7, 101, 'I thought this place was very spectacular!', 4.4, '2001-10-22', '2001-10-28', '2001-10-29 06:13:36');
# INSERT INTO pictures (visit_id, picture) VALUES (22, 'rh5nIkfFIP');
# INSERT INTO pictures (visit_id, picture) VALUES (22, '3Mtd6OHX0A');
# INSERT INTO pictures (visit_id, picture) VALUES (22, '4Ug1xxC3L4');
# INSERT INTO pictures (visit_id, picture) VALUES (22, '6Af0NF4Qj0');
# INSERT INTO pictures (visit_id, picture) VALUES (22, 'Y0DraCxpVj');
# INSERT INTO pictures (visit_id, picture) VALUES (22, 'nZY41qK500');
# INSERT INTO pictures (visit_id, picture) VALUES (22, 'xuQ8n0jvC4');
# INSERT INTO pictures (visit_id, picture) VALUES (22, 'wKXJcws2Fl');
# INSERT INTO pictures (visit_id, picture) VALUES (22, 'Ah0MWMnF2Y');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (23, 7, 61, 'I thought this place was very mind-blowing!', 3.1, '2000-04-23', '2000-04-23', '2000-04-24 03:55:02');
# INSERT INTO pictures (visit_id, picture) VALUES (23, 'r3By7FA3rX');
# INSERT INTO pictures (visit_id, picture) VALUES (23, 'HIN8Ctq64y');
# INSERT INTO pictures (visit_id, picture) VALUES (23, 'sL9emQ958P');
# INSERT INTO pictures (visit_id, picture) VALUES (23, 'Imd95SjIZ8');
# INSERT INTO pictures (visit_id, picture) VALUES (23, 'ozT4sQTRXJ');
# INSERT INTO pictures (visit_id, picture) VALUES (23, 'CACv5mSoTi');
# INSERT INTO pictures (visit_id, picture) VALUES (23, '7sbbn4Vdwc');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (24, 7, 31, 'I thought this place was very remarkable!', 4.6, '2019-11-14', '2019-11-16', '2019-11-17 22:07:27');
# INSERT INTO pictures (visit_id, picture) VALUES (24, 'QfHqPzMAIf');
# INSERT INTO pictures (visit_id, picture) VALUES (24, 'mYERirmTPr');
# INSERT INTO pictures (visit_id, picture) VALUES (24, 'srMMq0AJxP');
# INSERT INTO pictures (visit_id, picture) VALUES (24, 'OyiZi64Ous');
# INSERT INTO pictures (visit_id, picture) VALUES (24, 'w0g2GTMo8Q');
# INSERT INTO pictures (visit_id, picture) VALUES (24, 'GozWUXpSlO');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (8, 'BenMorales206', 'BenMorales206@gmail.com', 'random_file_path', 'Q,p=yB+2', '4ec84821003d350505527ecad60d959cc4d4c03cc1fdfc5a3ddb9d73ea89cc9c');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (25, 8, 2, 'I thought this place was very delightful!', 8.8, '2023-09-30', '2023-10-06', '2023-10-07 20:29:18');
# INSERT INTO pictures (visit_id, picture) VALUES (25, 'CTZHt0auDS');
# INSERT INTO pictures (visit_id, picture) VALUES (25, 'mJsUKe45JG');
# INSERT INTO pictures (visit_id, picture) VALUES (25, 'uZmo2XhSkT');
# INSERT INTO pictures (visit_id, picture) VALUES (25, '49XqYP0JK2');
# INSERT INTO pictures (visit_id, picture) VALUES (25, '3y2HJnxkrD');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (26, 8, 112, 'I thought this place was very mind-boggling!', 7.8, '2024-11-03', '2024-11-08', '2024-11-09 14:03:35');
# INSERT INTO pictures (visit_id, picture) VALUES (26, 'WVYp6zwjFj');
# INSERT INTO pictures (visit_id, picture) VALUES (26, 'wWQtUoFkG6');
# INSERT INTO pictures (visit_id, picture) VALUES (26, '56GMBxDevp');
# INSERT INTO pictures (visit_id, picture) VALUES (26, 'V4OL4uUNh3');
# INSERT INTO pictures (visit_id, picture) VALUES (26, '3F4rQViBL6');
# INSERT INTO pictures (visit_id, picture) VALUES (26, 'aPfLEnfnCo');
# INSERT INTO pictures (visit_id, picture) VALUES (26, 'qXy8TNNxV2');
# INSERT INTO pictures (visit_id, picture) VALUES (26, 'iynOUdyTbr');
# INSERT INTO pictures (visit_id, picture) VALUES (26, '9egwyLODGp');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (27, 8, 30, 'I thought this place was very astonishing!', 4.4, '2021-10-05', '2021-10-12', '2021-10-13 09:15:36');
# INSERT INTO pictures (visit_id, picture) VALUES (27, 'shPHlH0xpL');
# INSERT INTO pictures (visit_id, picture) VALUES (27, 'bSQQQB3PZc');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (9, 'AudreyPhillips90', 'AudreyPhillips90@gmail.com', 'random_file_path', '$b|a_oJ5', 'e47280867d59528333b5b2bca2c5a0cfd008eeba9872378c4df0391fa968fcbb');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (28, 9, 26, 'I thought this place was very magnificent!', 0.3, '2014-08-09', '2014-08-12', '2014-08-13 13:13:41');
# INSERT INTO pictures (visit_id, picture) VALUES (28, '9Gmt72DJeu');
# INSERT INTO pictures (visit_id, picture) VALUES (28, 'qXtp5an3Dq');
# INSERT INTO pictures (visit_id, picture) VALUES (28, 'N15LLutvO7');
# INSERT INTO pictures (visit_id, picture) VALUES (28, 'xieYnhzbLD');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (29, 9, 59, 'I thought this place was very memorable!', 0.0, '2001-10-11', '2001-10-18', '2001-10-19 03:40:02');
# INSERT INTO pictures (visit_id, picture) VALUES (29, 'fvdlcvWfuV');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (30, 9, 49, 'I thought this place was very spectacular!', 7.6, '2016-10-17', '2016-10-17', '2016-10-18 10:50:08');
# INSERT INTO pictures (visit_id, picture) VALUES (30, 'D4SwU2Dcn3');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (31, 9, 20, 'I thought this place was very marvelous!', 1.0, '2021-06-15', '2021-06-21', '2021-06-22 08:54:11');
# INSERT INTO pictures (visit_id, picture) VALUES (31, 'cfaHUh2Xf3');
# INSERT INTO pictures (visit_id, picture) VALUES (31, 'Hp3euoW30A');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (32, 9, 6, 'I thought this place was very terrific!', 9.9, '2005-10-11', '2005-10-15', '2005-10-16 23:30:02');
# INSERT INTO pictures (visit_id, picture) VALUES (32, 'O84YFApaFU');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (10, 'ElizabethClark104', 'ElizabethClark104@gmail.com', 'random_file_path', '3RJ9eMcw', '41c7ce5d5f5c2d63527e076286d57a44ca6bc6710cc9254f45ce095e05a58615');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (33, 10, 117, 'I thought this place was very eye-opening!', 9.0, '2007-10-21', '2007-10-28', '2007-10-29 23:32:47');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'SkYtuw71L3');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 's3P74lMozg');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'g6x6u0ipyL');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'h3Pcpedn5r');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'Wm7l60FSk7');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'W6eDqMXivA');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'ln46v7ohPF');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'kpsrwjW3fU');
# INSERT INTO pictures (visit_id, picture) VALUES (33, 'u0cpTk8hNc');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (34, 10, 98, 'I thought this place was very fun!', 2.9, '2005-04-28', '2005-05-05', '2005-05-06 05:47:25');
# INSERT INTO pictures (visit_id, picture) VALUES (34, 'A7t0RPWlg0');
# INSERT INTO pictures (visit_id, picture) VALUES (34, 'NKaU7DgtCO');
# INSERT INTO pictures (visit_id, picture) VALUES (34, 'OS14dvQCge');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (11, 'ChloeNguyen289', 'ChloeNguyen289@gmail.com', 'random_file_path', '?A6+=*RZ', '066dd3ebc2ef4cc495c9285b4460e4fb43bf595eeae9c64c705ce994b390f74e');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (35, 11, 106, 'I thought this place was very delightful!', 6.8, '2014-01-19', '2014-01-24', '2014-01-25 14:58:28');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 's59CwwQITJ');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'oVV16w1C4u');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'iPAGS0eKTC');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'vU69fTrU0g');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'qrObiP12FN');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'kCZjiwUOas');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'U6mJdlVURx');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'qInBJ5q02Q');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'mys14f6wwz');
# INSERT INTO pictures (visit_id, picture) VALUES (35, 'tWxuIIKKbQ');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (36, 11, 38, 'I thought this place was very astonishing!', 0.8, '2005-08-26', '2005-08-29', '2005-08-30 01:08:53');
# INSERT INTO pictures (visit_id, picture) VALUES (36, 'uKugm4pfyW');
# INSERT INTO pictures (visit_id, picture) VALUES (36, '82egPd9fxo');
# INSERT INTO pictures (visit_id, picture) VALUES (36, 'Dg5pjqo1Cu');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (12, 'AudreyKing277', 'AudreyKing277@gmail.com', 'random_file_path', ';3VF*b2<', '13052385430f281bd33292816f76621f0d902ae850aafe58f846dc58564405c1');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (37, 12, 87, 'I thought this place was very awesome!', 2.0, '2004-06-07', '2004-06-09', '2004-06-10 22:28:31');
# INSERT INTO pictures (visit_id, picture) VALUES (37, '36TF5NFcrF');
# INSERT INTO pictures (visit_id, picture) VALUES (37, 'ie3mxLizNI');
# INSERT INTO pictures (visit_id, picture) VALUES (37, 'FctSRPGkc8');
# INSERT INTO pictures (visit_id, picture) VALUES (37, 'biiM7x3Q4f');
# INSERT INTO pictures (visit_id, picture) VALUES (37, 'EA866qG3Sf');
# INSERT INTO pictures (visit_id, picture) VALUES (37, '4ytnnkDGNK');
# INSERT INTO pictures (visit_id, picture) VALUES (37, 'Tzhb4THc5z');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (38, 12, 43, 'I thought this place was very unforgettable!', 2.2, '2015-03-27', '2015-04-02', '2015-04-03 01:02:37');
# INSERT INTO pictures (visit_id, picture) VALUES (38, '8ohmyHowjv');
# INSERT INTO pictures (visit_id, picture) VALUES (38, '0nqcs8ZvqI');
# INSERT INTO pictures (visit_id, picture) VALUES (38, 'fAc10PJX6V');
# INSERT INTO pictures (visit_id, picture) VALUES (38, 'WZMMV7L6Wy');
# INSERT INTO pictures (visit_id, picture) VALUES (38, 'CKjOsj8W0q');
# INSERT INTO pictures (visit_id, picture) VALUES (38, 'TBffnyEpGT');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (39, 12, 80, 'I thought this place was very memorable!', 8.7, '2016-08-16', '2016-08-17', '2016-08-18 01:22:28');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'MtbCXL8Dr5');
# INSERT INTO pictures (visit_id, picture) VALUES (39, '565qxthoxL');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'q5IehaaKNe');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'CCqEkPV8ti');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'RNB7CcjC8D');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'Z0jT5HjFrY');
# INSERT INTO pictures (visit_id, picture) VALUES (39, '3h3wz7LVtv');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'JWVJdCqNfT');
# INSERT INTO pictures (visit_id, picture) VALUES (39, '2hDJ7l6ZP2');
# INSERT INTO pictures (visit_id, picture) VALUES (39, 'i44DtUwlAC');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (13, 'AudreyLopez110', 'AudreyLopez110@gmail.com', 'random_file_path', 'm&ea0bB$', '6fbe504325aed71917ece99494eef2938cb39fc76f70f96780b62ddbe1b39b19');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (40, 13, 32, 'I thought this place was very amazing!', 0.3, '2017-03-31', '2017-04-07', '2017-04-08 17:57:12');
# INSERT INTO pictures (visit_id, picture) VALUES (40, 'WoEopRtuq7');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (41, 13, 95, 'I thought this place was very breathtaking!', 6.1, '2014-03-09', '2014-03-14', '2014-03-15 23:33:17');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'fUqiqivOBS');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'naoct19Duu');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'naMs6kEZOo');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'bya6UY2eRK');
# INSERT INTO pictures (visit_id, picture) VALUES (41, '25rBH73pRa');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'vzE6fbYey9');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'TcnC9KYV74');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'QJ9emMt5TJ');
# INSERT INTO pictures (visit_id, picture) VALUES (41, 'wY3pnhMP6y');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (42, 13, 89, 'I thought this place was very jaw-dropping!', 7.6, '2011-11-12', '2011-11-15', '2011-11-16 17:40:43');
# INSERT INTO pictures (visit_id, picture) VALUES (42, 'P98oq6vye0');
# INSERT INTO pictures (visit_id, picture) VALUES (42, 'DALdWJICaV');
# INSERT INTO pictures (visit_id, picture) VALUES (42, '6klWQJIwnh');
# INSERT INTO pictures (visit_id, picture) VALUES (42, '59JeilmxUF');
# INSERT INTO pictures (visit_id, picture) VALUES (42, 'd5HNgRohpT');
# INSERT INTO pictures (visit_id, picture) VALUES (42, '1IGGAAW6T2');
# INSERT INTO pictures (visit_id, picture) VALUES (42, 'Tzj1mWeNmW');
# INSERT INTO pictures (visit_id, picture) VALUES (42, 'qWSB2BH2oy');
# INSERT INTO pictures (visit_id, picture) VALUES (42, 'SxIPjaauFE');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (14, 'AriaGreen101', 'AriaGreen101@gmail.com', 'random_file_path', 'Xscf3|}!', 'c4e1f6af1d52487f54b9930a7ef3e341917b0e3c923b5a280273abedf9cac720');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (43, 14, 41, 'I thought this place was very awesome!', 2.2, '2015-10-30', '2015-11-03', '2015-11-04 21:07:16');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'x7e5FMKnPB');
# INSERT INTO pictures (visit_id, picture) VALUES (43, '0Qvb2mElll');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'czeYHPeCR0');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'vPYfSeL0sd');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'LcCWAlbuiX');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'ottWIRc0lp');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'ZPsqCKE7DT');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'GERTdOZCuv');
# INSERT INTO pictures (visit_id, picture) VALUES (43, 'widQCakjcT');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (44, 14, 52, 'I thought this place was very remarkable!', 7.4, '2021-04-22', '2021-04-25', '2021-04-26 17:46:09');
# INSERT INTO pictures (visit_id, picture) VALUES (44, 'WCirS59h19');
# INSERT INTO pictures (visit_id, picture) VALUES (44, 'dcddEUlr8K');
# INSERT INTO pictures (visit_id, picture) VALUES (44, 'u2NyBrYopE');
# INSERT INTO pictures (visit_id, picture) VALUES (44, 'lKcr5c3RHH');
# INSERT INTO pictures (visit_id, picture) VALUES (44, 'OmV4ji2puw');
# INSERT INTO pictures (visit_id, picture) VALUES (44, '0AdU2enMkJ');
# INSERT INTO pictures (visit_id, picture) VALUES (44, 'CV3LIpkAiJ');
# INSERT INTO pictures (visit_id, picture) VALUES (44, '8t1SqugHLW');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (45, 14, 31, 'I thought this place was very wonderful!', 9.2, '2016-11-28', '2016-11-28', '2016-11-29 11:09:02');
# INSERT INTO pictures (visit_id, picture) VALUES (45, '1CJESrCKeY');
# INSERT INTO pictures (visit_id, picture) VALUES (45, 'OAMumB108N');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (46, 14, 100, 'I thought this place was very enjoyable!', 9.6, '2014-06-06', '2014-06-09', '2014-06-10 06:02:57');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'L3Gvy80OSz');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'oDif30W18M');
# INSERT INTO pictures (visit_id, picture) VALUES (46, '87xQbBnwUt');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'hpMUuSBvud');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'ZJIgm1whBN');
# INSERT INTO pictures (visit_id, picture) VALUES (46, '7Fmm6xskoJ');
# INSERT INTO pictures (visit_id, picture) VALUES (46, '4YG25fQYZG');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'XB04eYgUVP');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'gpvhDCJ770');
# INSERT INTO pictures (visit_id, picture) VALUES (46, 'Sxec1wDlJn');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (47, 14, 20, 'I thought this place was very enjoyable!', 1.6, '2006-01-03', '2006-01-06', '2006-01-07 14:53:46');
# INSERT INTO pictures (visit_id, picture) VALUES (47, '8tFXzrsAhZ');
# INSERT INTO pictures (visit_id, picture) VALUES (47, 'ogdNsTtEkl');
# INSERT INTO pictures (visit_id, picture) VALUES (47, 'DKb6hFQO3P');
# INSERT INTO pictures (visit_id, picture) VALUES (47, '9HpsxUpQqW');
# INSERT INTO pictures (visit_id, picture) VALUES (47, 'iTRtMJMul7');
# INSERT INTO pictures (visit_id, picture) VALUES (47, 'e40fQrhwbn');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (15, 'AveryHill170', 'AveryHill170@gmail.com', 'random_file_path', 'qW[|5ryV', '8358fd87d9c45268bd8af816dad0ba183dbc5ea8da1f44db32a25c502e878eb4');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (48, 15, 32, 'I thought this place was very astonishing!', 8.0, '2020-12-26', '2020-12-26', '2020-12-27 18:59:32');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'HcpcG3mn3q');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'FJFb4yoVWO');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'xc6stiS9jr');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'INokrzwKWA');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'KRQkhxLnAQ');
# INSERT INTO pictures (visit_id, picture) VALUES (48, '25WgcvMGcW');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'oXdIEbNZks');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 's4e2CcAhMC');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'N2UnUhAVSp');
# INSERT INTO pictures (visit_id, picture) VALUES (48, 'hwoNug2HYl');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (49, 15, 10, 'I thought this place was very breathtaking!', 2.0, '2007-08-06', '2007-08-07', '2007-08-08 11:35:52');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'L8KeAUGbzJ');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'x4tEOdyzeE');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'YiagaYxgkK');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'MXbaRzAo1T');
# INSERT INTO pictures (visit_id, picture) VALUES (49, '1zzSL8xGsw');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'hCYZ9ZVJnu');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'KF5mfdL63w');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'TWcODSUuQw');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'Uh2dHSI5Mh');
# INSERT INTO pictures (visit_id, picture) VALUES (49, 'vAynGycW6H');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (50, 15, 50, 'I thought this place was very mind-boggling!', 9.3, '2001-03-07', '2001-03-14', '2001-03-15 06:22:11');
# INSERT INTO pictures (visit_id, picture) VALUES (50, '7sXRIWzYq5');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (16, 'KaiNguyen293', 'KaiNguyen293@gmail.com', 'random_file_path', '|GGtY8C=', '6c38f194167b9f215bd9a64a1bf077db6b8270e047a736635551bf439a8f21d7');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (51, 16, 43, 'I thought this place was very delightful!', 6.5, '2014-01-23', '2014-01-30', '2014-01-31 21:42:27');
# INSERT INTO pictures (visit_id, picture) VALUES (51, 'Jiz2wJVL2x');
# INSERT INTO pictures (visit_id, picture) VALUES (51, 'uGFiUKrooF');
# INSERT INTO pictures (visit_id, picture) VALUES (51, 'rSf4z10RBR');
# INSERT INTO pictures (visit_id, picture) VALUES (51, 'tRP16ywuH9');
# INSERT INTO pictures (visit_id, picture) VALUES (51, 'kxm2mLA2tD');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (52, 16, 50, 'I thought this place was very eye-opening!', 7.4, '2020-06-19', '2020-06-23', '2020-06-24 19:12:05');
# INSERT INTO pictures (visit_id, picture) VALUES (52, 'pVElNyeYm6');
# INSERT INTO pictures (visit_id, picture) VALUES (52, '1PQhLmh8k7');
# INSERT INTO pictures (visit_id, picture) VALUES (52, 'YxH0KdJcdJ');
# INSERT INTO pictures (visit_id, picture) VALUES (52, 'OXFDVf2s0A');
# INSERT INTO pictures (visit_id, picture) VALUES (52, 'feVp6KqknE');
# INSERT INTO pictures (visit_id, picture) VALUES (52, '8oTqkAuMrZ');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (53, 16, 67, 'I thought this place was very fantastic!', 9.2, '2016-06-17', '2016-06-19', '2016-06-20 04:48:30');
# INSERT INTO pictures (visit_id, picture) VALUES (53, 'WWhOI1LL67');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (54, 16, 8, 'I thought this place was very breathtaking!', 9.2, '2006-05-11', '2006-05-15', '2006-05-16 22:31:46');
# INSERT INTO pictures (visit_id, picture) VALUES (54, 'GHNYVZiK4Y');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (17, 'JosephSpeer268', 'JosephSpeer268@gmail.com', 'random_file_path', '0@$LYElb', '9986882130de773aa0bc3b1eade0cc75ca711983d25e91020d3b3024087abebe');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (55, 17, 109, 'I thought this place was very fabulous!', 3.3, '2007-11-07', '2007-11-13', '2007-11-14 09:53:16');
# INSERT INTO pictures (visit_id, picture) VALUES (55, 'SzEi4qrRPz');
# INSERT INTO pictures (visit_id, picture) VALUES (55, 'exVP5sqxyn');
# INSERT INTO pictures (visit_id, picture) VALUES (55, '2swxNYkK74');
# INSERT INTO pictures (visit_id, picture) VALUES (55, '4vyacFn0vp');
# INSERT INTO pictures (visit_id, picture) VALUES (55, 'wsWoWPnanD');
# INSERT INTO pictures (visit_id, picture) VALUES (55, 'BVE2FvQoD7');
# INSERT INTO pictures (visit_id, picture) VALUES (55, 'ecGM22BpiK');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (56, 17, 96, 'I thought this place was very mind-boggling!', 6.9, '2015-01-28', '2015-01-28', '2015-01-29 14:45:16');
# INSERT INTO pictures (visit_id, picture) VALUES (56, 'tSxiWzrHGg');
# INSERT INTO pictures (visit_id, picture) VALUES (56, 'MqCvqJjIgd');
# INSERT INTO pictures (visit_id, picture) VALUES (56, 'O3fAYzH9Rr');
# INSERT INTO pictures (visit_id, picture) VALUES (56, 'kvtj1U3rJf');
# INSERT INTO pictures (visit_id, picture) VALUES (56, 'IT997GOaIZ');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (57, 17, 29, 'I thought this place was very phenomenal!', 3.0, '2006-04-06', '2006-04-07', '2006-04-08 09:08:49');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'iSaaZAfqle');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'Yq5inFCw02');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'I9uZPdeW67');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'YFbiEiu0Cd');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'qikfeVjIkj');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'jHmj4Uj6Df');
# INSERT INTO pictures (visit_id, picture) VALUES (57, 'n17sMo1lhC');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (18, 'EllaSullivan673', 'EllaSullivan673@gmail.com', 'random_file_path', ';OT@9-|D', '2f6fcc2de50e4c03df49966cb69f941ba8ba0c46469bba955d136dabe1621b53');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (58, 18, 75, 'I thought this place was very unbelievable!', 1.4, '2018-08-27', '2018-08-31', '2018-09-01 05:17:46');
# INSERT INTO pictures (visit_id, picture) VALUES (58, 'wSiBZLolPP');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (19, 'JulianPhillips325', 'JulianPhillips325@gmail.com', 'random_file_path', 'l4STqTNl', '0d92cc6a399d4b2cc42cb88975d2f932ed4e3eba6a15890527d0442fc227be17');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (59, 19, 94, 'I thought this place was very unbelievable!', 9.7, '2024-10-26', '2024-10-30', '2024-10-31 01:54:01');
# INSERT INTO pictures (visit_id, picture) VALUES (59, 'XK95KwY4Kd');
# INSERT INTO pictures (visit_id, picture) VALUES (59, 'QFB7YKL7Ob');
# INSERT INTO pictures (visit_id, picture) VALUES (59, 'WiIHwpyAOK');
# INSERT INTO pictures (visit_id, picture) VALUES (59, 'cTrIKKGDda');
# INSERT INTO pictures (visit_id, picture) VALUES (59, 'dsNhglg5Wg');
# INSERT INTO pictures (visit_id, picture) VALUES (59, 'PAycWmxl9Q');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (60, 19, 73, 'I thought this place was very exciting!', 0.4, '2004-03-18', '2004-03-20', '2004-03-21 13:54:03');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'ZFsU4ZgjXu');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'UI1HYDspot');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'fI0MVsTSrD');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'OVu0FWh8oo');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'vflKVboAxL');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'a2tAx6kotb');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'HhSg2vFKh6');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'DMUGJrteLx');
# INSERT INTO pictures (visit_id, picture) VALUES (60, 'L23u4dbUU2');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (61, 19, 17, 'I thought this place was very unbelievable!', 9.2, '2018-12-06', '2018-12-08', '2018-12-09 20:25:40');
# INSERT INTO pictures (visit_id, picture) VALUES (61, 'YpBthfmzUu');
# INSERT INTO user_info (user_id, username, email, profile_pic, salt, password_hash) VALUES (20, 'ClaireBaker344', 'ClaireBaker344@gmail.com', 'random_file_path', 'CP7GSFVP', 'a6c10ef13b5abd0215c0803e30f667f27c5277820f120b9131e06f0eb144ccf0');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (62, 20, 92, 'I thought this place was very spectacular!', 2.5, '2021-08-22', '2021-08-24', '2021-08-25 08:14:44');
# INSERT INTO pictures (visit_id, picture) VALUES (62, 'rSghFyFpXW');
# INSERT INTO pictures (visit_id, picture) VALUES (62, 'ue9crrJILy');
# INSERT INTO pictures (visit_id, picture) VALUES (62, 'lXwqGqfXjC');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES (63, 20, 17, 'I thought this place was very extraordinary!', 0.0, '2020-07-31', '2020-08-02', '2020-08-03 09:04:56');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'MPc6VngxKh');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'aqyPMDTc0K');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'QN0aqUegWK');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'n3ZiXfjjIR');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'HCsLXMOw4m');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'lURYPt29qN');
# INSERT INTO pictures (visit_id, picture) VALUES (63, '8IPUQsIyEe');
# INSERT INTO pictures (visit_id, picture) VALUES (63, 'vQ2Q85fapT');
# INSERT INTO visits (visit_id, user_id, city_id, review_text, rating, start_date, end_date, time_inputted)
#         VALUES

# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (17, 74, '2013-05-06 02:22:26');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (17, 118, '2007-09-21 14:24:32');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (17, 45, '2024-01-17 13:48:53');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 88, '2018-04-24 23:24:12');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 65, '2020-06-21 06:00:50');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 4, '2001-10-15 07:05:46');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 30, '2014-10-05 11:13:23');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 60, '2023-02-12 23:47:45');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 3, '2008-06-12 20:32:10');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 62, '2020-08-29 13:07:09');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 14, '2022-10-14 19:34:36');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 40, '2012-04-06 05:48:38');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 32, '2020-03-20 07:25:32');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 101, '2019-11-10 13:47:56');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (18, 19, '2004-07-01 18:03:27');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 73, '2022-11-06 14:27:06');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 105, '2018-02-17 19:25:49');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 7, '2015-06-26 14:04:35');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 56, '2019-10-14 15:27:53');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 53, '2010-11-24 17:32:01');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 18, '2010-04-10 04:04:48');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 89, '2015-09-15 09:22:38');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 96, '2013-04-11 13:36:20');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 69, '2001-10-03 11:26:00');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 26, '2001-02-19 23:50:58');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 13, '2024-05-04 16:30:49');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 55, '2013-04-28 02:46:21');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 117, '2009-09-18 15:42:19');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (19, 36, '2014-07-16 04:32:12');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 77, '2009-11-22 21:18:22');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 89, '2005-11-16 16:07:24');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 18, '2010-10-29 15:56:19');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 34, '2009-08-12 19:36:03');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 31, '2020-11-13 11:23:37');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 11, '2020-07-01 03:10:34');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 22, '2019-06-26 05:13:26');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 72, '2009-08-29 08:39:47');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 101, '2002-11-19 03:20:09');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 97, '2002-02-19 06:07:01');
# INSERT INTO wishlist (user_id, city_id, time_inputted)
#             VALUES (20, 81, '2011-12-28 10:43:55');

# %%
import random

def generate_connections_inserts(num_users, max_connections_per_user):
    insert_statements = []
    for user_id1 in range(1, num_users + 1):
        num_connections = random.randint(1, max_connections_per_user)
        
        connections = random.sample(range(1, num_users + 1), num_connections)
        connections = [user_id2 for user_id2 in connections if user_id2 != user_id1]
        
        for user_id2 in connections:
      
            smaller_id, larger_id = sorted([user_id1, user_id2])
            insert_statement = f"INSERT INTO connections (user_id1, user_id2) VALUES ({smaller_id}, {larger_id});"
            
            if insert_statement not in insert_statements: 
                insert_statements.append(insert_statement)

    return insert_statements

num_users = 20 
max_connections_per_user = 15 
insert_statements = generate_connections_inserts(num_users, max_connections_per_user)

for statement in insert_statements:
    print(statement)
# Out:
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 8);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 6);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 4);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 5);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 3);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 5);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 4);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 6);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 9);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 4);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 7);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (4, 5);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 9);
# INSERT INTO connections (user_id1, user_id2) VALUES (6, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 6);
# INSERT INTO connections (user_id1, user_id2) VALUES (6, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (6, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 11);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 8);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 8);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 8);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 16);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 9);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 16);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (6, 9);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 11);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (10, 16);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 10);
# INSERT INTO connections (user_id1, user_id2) VALUES (11, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (11, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (11, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 11);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 11);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 11);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (12, 16);
# INSERT INTO connections (user_id1, user_id2) VALUES (12, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (12, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (6, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (12, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 12);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (11, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 13);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 16);
# INSERT INTO connections (user_id1, user_id2) VALUES (14, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (14, 15);
# INSERT INTO connections (user_id1, user_id2) VALUES (11, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (14, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (14, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (14, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 14);
# INSERT INTO connections (user_id1, user_id2) VALUES (15, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (5, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (16, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (9, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (17, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (1, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 17);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (6, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (2, 18);
# INSERT INTO connections (user_id1, user_id2) VALUES (16, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (19, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (8, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 19);
# INSERT INTO connections (user_id1, user_id2) VALUES (13, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (12, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (7, 20);
# INSERT INTO connections (user_id1, user_id2) VALUES (3, 20);
